# %% [markdown]
# # Qn1 Read data set to python environment

# %%
#To read data to python
import pandas as pd
data=pd.read_csv('Downloads\Data science\cars_data.csv')
data
# Out:
#          Make        Model    Nickname Car Gender Buyer Gender  Buyer Age  \
# 0      Suzuki       Vitara  Philippine     Female       Female         51
# 1       Honda        S2000      Henrik       Male         Male         30
# 2         BMW           Z4      Lebbie       Male       Female         54
# 3      Toyota       Tacoma    Jefferey     Female         Male         68
# 4        Ford      Festiva     Glendon     Female         Male         70
# ...       ...          ...         ...        ...          ...        ...
# 9995    Mazda      Tribute      Cooper       Male         Male         44
# 9996      GMC  Sierra 2500         Dud       Male         Male         40
# 9997  Mercury      Mariner     Chariot       Male         Male         37
# 9998   Daewoo      Leganza       Dynah     Female       Female         21
# 9999   Toyota      Sequoia    Zedekiah     Female         Male         21
#
#            Buzzword      Country             City  Dealer Latitude  \
# ...

# %% [markdown]
# # Qn 2 Check whether any null values present in the data

# %%
data.isna().sum()
# Out:
# Make                 0
# Model                0
# Nickname             0
# Car Gender           0
# Buyer Gender         0
# Buyer Age            0
# Buzzword             0
# Country              0
# City                 0
# Dealer Latitude      0
# Dealer Longitude     0
# Color                0
# New Car              0
# Purchase Date        0
# Sale Price           0
# Discount             0
# Resell Price         0
# 5-yr Depreciation    0
# Top Speed            0
# 0-60 Time            0
# dtype: int64

# %% [markdown]
# From this it is clear that no null values present in data.

# %% [markdown]
# # Qn 3 Bar graph of male vs female buyers participated in the sale

# %%
import matplotlib.pyplot as plt
import seaborn as sns
#To give title to the graph
plt.title('Bar graph of male vs female buyers participated in the sale',fontsize=12)
#To plot the graph
sns.countplot(x='Buyer Gender',data=data)
# Out:
# <AxesSubplot:title={'center':'Bar graph of male vs female buyers participated in the sale'}, xlabel='Buyer Gender', ylabel='count'>

# %% [markdown]
# # Qn 4 Top 5 cars based on their sales price

# %% [markdown]
# # METHOD 1

# %%
#To find the entire row of top 5 cars based on their sales price
data.nlargest(5,['Sale Price'])
# Out:
#             Make      Model   Nickname Car Gender Buyer Gender  Buyer Age  \
# 5984  Volkswagen  Jetta III    Rachael     Female       Female         73
# 1270        Audi         A6      Thorn       Male         Male         75
# 3460       Lexus         LX      Aldin     Female         Male         38
# 9032       Mazda       MX-6  Sylvester     Female         Male         26
# 302        Lexus         ES       Brig     Female         Male         39
#
#                Buzzword   Country           City  Dealer Latitude  \
# 5984               core    Russia    Krasnoyarka        59.418208
# 1270           function    Latvia        Līgatne        57.236340
# 3460           software  Malaysia      Pasir Mas         6.109065
# 9032  internet solution    Russia  Krutaya Gorka        55.369917
# 302         user-facing    Canada       Langford        48.447463
#
#       Dealer Longitude   Color  New Car Purchase Date  Sale Price  Discount  \
# ...

# %% [markdown]
# # METHOD 2

# %%
#To display both the columns 'model' ,'sales price' and easily find top 5 models based on their sale price 
data1={'Model':data['Model'],'Sale Price':data['Sale Price']}
data3=pd.DataFrame(data1)
data3
# Out:
#             Model  Sale Price
# 0          Vitara    54806.14
# 1           S2000    51826.30
# 2              Z4    82929.14
# 3          Tacoma    56928.66
# 4         Festiva    77201.26
# ...           ...         ...
# 9995      Tribute    58580.65
# 9996  Sierra 2500    75229.74
# 9997      Mariner    34755.44
# 9998      Leganza    98725.42
# 9999      Sequoia    96769.78
#
# [10000 rows x 2 columns]

# %%
data3.nlargest(5,['Sale Price'])
# Out:
#           Model  Sale Price
# 5984  Jetta III    99997.65
# 1270         A6    99991.91
# 3460         LX    99983.38
# 9032       MX-6    99978.17
# 302          ES    99973.44

# %% [markdown]
# # Qn 5 Find the least 5 cars based on their Resell price.

# %% [markdown]
# # METHOD 1

# %%
data.nsmallest(5,['Resell Price'])
# Out:
#             Make        Model Nickname Car Gender Buyer Gender  Buyer Age  \
# 2446   Chevrolet         1500  Corenda       Male       Female         25
# 4933         GMC  Savana 1500     Lark     Female       Female         34
# 566       Jaguar           XF   Payton     Female         Male         64
# 2538  Mitsubishi       3000GT     Thia     Female       Female         25
# 5869    Infiniti          G37    Sonny       Male         Male         20
#
#             Buzzword      Country              City  Dealer Latitude  \
# 2446   collaboration  Philippines           Tubigan         8.490877
# 4933     interactive       Poland       Śródmieście        53.838651
# 566        Visionary      Nigeria       Ikot-Ekpene         5.174447
# 2538  well-modulated        China        Yanweigang        34.509325
# 5869      optimizing       France  Clermont-Ferrand        45.786764
#
#       Dealer Longitude      Color  New Car Purchase Date  Sale Price  \
# ...

# %% [markdown]
# # METHOD 2

# %%
#To display both the columns 'model' ,'Resell price' and easily find least 5 models based on their sale price 
data4={'Model':data['Model'],'Resell Price':data['Resell Price']}
data5=pd.DataFrame(data1)
data5
# Out:
#             Model  Resell Price
# 0          Vitara      33858.32
# 1           S2000       2989.28
# 2              Z4      35049.16
# 3          Tacoma       8236.15
# 4         Festiva      32765.76
# ...           ...           ...
# 9995      Tribute      42640.82
# 9996  Sierra 2500      21115.58
# 9997      Mariner       2731.25
# 9998      Leganza      18718.58
# 9999      Sequoia       4545.95
#
# [10000 rows x 2 columns]

# %%
data5.nsmallest(5,['Resell Price'])
# Out:
#             Model  Resell Price
# 2446         1500       2000.84
# 4933  Savana 1500       2005.44
# 566            XF       2014.09
# 2538       3000GT       2017.24
# 5869          G37       2017.83
